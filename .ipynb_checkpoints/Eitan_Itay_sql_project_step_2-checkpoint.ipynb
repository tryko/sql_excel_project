# %% [markdown]
# 1. Create a flat table per each order (flat – for every order bring every relevant information). For example: users registration, country, category etc. Save it to csv or excel file. PLEASE  validate the data.
#
# 2. Read the extra text file that can be find here to your current excel

# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
# lets also use sidetable to check which column have nan value - pip install sidetable
# need to make sure the peckage openpyxl - pip install openpyxl 
#import sidetable

# %%
db_config = {'user': 'practicum_student',         # username             
                      'pwd': 's65BlTKV3faNIGhmvJVzOqhs', # password             
                      'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',       #host URL      
                      'port': 6432,              # connection port             
                      'db': 'data-analyst-web-store'}          # the name of the database

connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(db_config['user'],
                                                                     db_config['pwd'],
                                                                       db_config['host'],
                                                                       db_config['port'],
                                                                       db_config['db'])

engine = create_engine(connection_string, connect_args={'sslmode':'require'})

# %%
def queryResult(q):
    return pd.io.sql.read_sql(q, con = engine)

# %%
query1 = '''
            select
                *
            from
            (
                select  
                    orders.order_id, orders.date,
                    Registration,
                    campaign.campaign_id, campaign.source,  campaign.start_date as camp_start_date, campaign.end_date as camp_end_date,
                    customer_info.customer_id, customer_info.membership, customer_info.gender,
                    countries.country_id, countries.symbol, countries.country,
                    ab_allocation.ab_test_id, ab_allocation.id, ab_allocation.group,
                    ab_info.description, ab_info.start_date as ab_start_date, ab_info.end_date as ab_end_date,
                    order_details.amount,
                    items.item_id, items.price, items.item,
                    vendors.vendor_id, vendors.vendor,
                    categories.category_id, categories.category, categories.us_ship, categories.other_ship,
                    row_number() over (partition by orders.order_id order BY (select null)) as duprank
                from 
                    orders 
                    left join registration on orders.customer_id = registration.customer_id
                    left join campaign on campaign.campaign_id = registration.campaign_id
                    left join customer_info on customer_info.customer_id = orders.customer_id
                    left join countries on countries.country_id = customer_info.country_id
                    left join ab_allocation on ab_allocation.customer_id = orders.customer_id
                    left join ab_info on ab_info.ab_test_id = ab_allocation.ab_test_id
                    left join order_details on order_details.order_id = orders.order_id
                    left join items on items.item_id = order_details.item_id
                    left join vendors on vendors.vendor_id = items.vendor_id
                    left join categories on categories.category_id = items.category_id
            ) as T
            WHERE duprank = 1 
         '''


df = queryResult(query1)

display('duplicated: ',df[df.duplicated()])
display('na:', df[df.isna().any(axis=1)])
display('no filter: ',df)
# Out:
# 'duplicated: '
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'na:'
#       order_id       date                    registration  campaign_id  \
# 921        922 2021-03-12   (56,"2021-02-16 00:00:00",11)           11
# 983        984 2021-04-21  (177,"2021-02-01 00:00:00",11)           11
# 1048      1049 2021-05-26  (479,"2021-03-12 00:00:00",14)           14
# 1089      1090 2021-06-19  (197,"2021-06-09 00:00:00",13)           13
# 1109      1110 2021-06-27   (56,"2021-02-16 00:00:00",11)           11
# 1138      1139 2021-07-10  (210,"2021-05-28 00:00:00",14)           14
# 1157      1158 2021-07-23  (267,"2021-03-10 00:00:00",12)           12
# 1168      1169 2021-07-31  (164,"2021-04-30 00:00:00",12)           12
# 1178      1179 2021-08-02  (305,"2021-02-11 00:00:00",11)           11
# 1196      1197 2021-08-05   (68,"2021-08-05 00:00:00",14)           14
# 1197      1198 2021-08-05  (306,"2021-03-02 00:00:00",12)           12
#
#           source camp_start_date camp_end_date  customer_id membership  \
# 921     Facebook      2020-11-13    2021-03-10           56        yes
# 983     Facebook      2020-11-13    2021-03-10          177        yes
# 1048  Google Ads      2021-03-12    2021-08-05          479         no
# 1089    Facebook      2021-04-01    2021-07-12          197         no
# 1109    Facebook      2020-11-13    2021-03-10           56        yes
# 1138  Google Ads      2021-03-12    2021-08-05          210        yes
# 1157     YouTube      2021-02-23    2021-06-30          267         no
# 1168     YouTube      2021-02-23    2021-06-30          164        yes
# 1178    Facebook      2020-11-13    2021-03-10          305        yes
# 1196  Google Ads      2021-03-12    2021-08-05           68         no
# 1197     YouTube      2021-02-23    2021-06-30          306         no
#
#       gender  ...  item_id   price  \
# 921   Female  ...       41   13.49
# 983   Female  ...      102   59.99
# 1048    Male  ...       42  320.00
# 1089  Female  ...       38  120.00
# 1109  Female  ...      121   45.99
# 1138  Female  ...        4   25.99
# 1157  Female  ...      142   72.99
# 1168    Male  ...       11   19.49
# 1178  Female  ...       77   77.50
# 1196  Female  ...      161    8.96
# 1197    Male  ...       49   28.79
#
#                                                    item  vendor_id  \
# 921                      Eye Shadow Palette - 15 shades         24
# 983                    One Piece Vol.1 1st Edition - JP          9
# 1048                                          Face Mask         24
# 1089  Dragon Ball Z - Officially Licensed Dragon Bal...         15
# 1109  Roku Streaming Stick With HD/4K/HDR Streaming ...          1
# 1138  12/14 inch long Aluminum Pizza Shovel With Lon...         18
# 1157  Timberland Brooklyn Alpine Chukka Black Nubuck...          2
# 1168                           500 Pieces Castle Puzzle         20
# 1178                                       Lego Classic         13
# 1196                                            Yahtzee         20
# 1197                   Funko Pop! PAIN Glow In The Dark          7
#
#                     vendor category_id        category us_ship other_ship  \
# 921                beautyo          10     Beauty Care    9.99      19.99
# 983      excellent-shop666           3           Books    9.99      14.99
# 1048               beautyo          10     Beauty Care    9.99      19.99
# 1089                pixfab           4    Collectibles    9.99      14.99
# 1109                doronk           1     Electronics   19.99      24.99
# 1138  magicglobalgadgets17           8         Kitchen    9.99      14.99
# 1157                zoro12           2         Fashion    9.99      14.99
# 1168                trainz           6  Toys & Hobbies    4.99       9.99
# 1178          ignitionline           6  Toys & Hobbies    4.99       9.99
# 1196                trainz           6  Toys & Hobbies    4.99       9.99
# 1197              fullstar           4    Collectibles    9.99      14.99
#
#       duprank
# 921         1
# 983         1
# 1048        1
# 1089        1
# 1109        1
# 1138        1
# 1157        1
# 1168        1
# 1178        1
# 1196        1
# 1197        1
#
# [11 rows x 30 columns]
# 'no filter: '
#       order_id       date                    registration  campaign_id  \
# 0            1 2019-10-02   (214,"2019-06-15 00:00:00",3)            3
# 1            2 2019-10-02   (459,"2019-06-29 00:00:00",2)            2
# 2            3 2019-10-02   (489,"2019-05-29 00:00:00",1)            1
# 3            4 2019-10-03   (127,"2019-05-02 00:00:00",2)            2
# 4            5 2019-10-03   (174,"2019-09-24 00:00:00",3)            3
# ...        ...        ...                             ...          ...
# 1195      1196 2021-08-05    (11,"2020-05-06 00:00:00",9)            9
# 1196      1197 2021-08-05   (68,"2021-08-05 00:00:00",14)           14
# 1197      1198 2021-08-05  (306,"2021-03-02 00:00:00",12)           12
# 1198      1199 2021-08-05  (422,"2020-11-15 00:00:00",10)           10
# 1199      1200 2021-08-05   (485,"2020-08-23 00:00:00",9)            9
#
#           source camp_start_date camp_end_date  customer_id membership  \
# 0     Google Ads      2019-05-30    2019-12-31          214        yes
# 1       Facebook      2019-05-30    2019-12-31          459        yes
# 2        YouTube      2019-05-30    2019-12-31          489         no
# 3       Facebook      2019-05-30    2019-12-31          127        yes
# 4     Google Ads      2019-05-30    2019-12-31          174         no
# ...          ...             ...           ...          ...        ...
# 1195  Google Ads      2020-05-01    2020-09-01           11         no
# 1196  Google Ads      2021-03-12    2021-08-05           68         no
# 1197     YouTube      2021-02-23    2021-06-30          306         no
# 1198     YouTube      2020-08-12    2020-12-31          422         no
# 1199  Google Ads      2020-05-01    2020-09-01          485         no
#
#       gender  ...  item_id   price  \
# 0       Male  ...      156   13.99
# 1     Female  ...       52   84.99
# 2       Male  ...      116   21.95
# 3     Female  ...       30   95.95
# 4       Male  ...      136   29.95
# ...      ...  ...      ...     ...
# 1195    Male  ...       70   21.99
# 1196  Female  ...      161    8.96
# 1197    Male  ...       49   28.79
# 1198  Female  ...      139  139.99
# 1199  Female  ...       23    9.99
#
#                                                    item  vendor_id  \
# 0       Wilson Official Size NFL Ball American Football         21
# 1                      GK61s Mechanical Gaming Keyboard         20
# 2                          Revlon Super Lusrous 3 piece         24
# 3              Cross Trainer Air Walker Glider Home Gym         12
# 4     Star Wars: the Old Republic - Legends Ser.: Fa...          6
# ...                                                 ...        ...
# 1195                                     Kids Gamer Tee          3
# 1196                                            Yahtzee         20
# 1197                   Funko Pop! PAIN Glow In The Dark          7
# 1198                       The Dangling Man 1st Edition         19
# 1199  Best Friend Bracelets for 2 Matching Yin Yang ...          5
#
#               vendor category_id        category us_ship other_ship  duprank
# 0        vhbw-online           5  Sporting Goods   14.99      19.99        1
# 1             trainz           9          Gaming    9.99      14.99        1
# 2            beautyo          10     Beauty Care    9.99      19.99        1
# 3          lumo-shop           5  Sporting Goods   14.99      19.99        1
# 4     senior pac-man           3           Books    9.99      14.99        1
# ...              ...         ...             ...     ...        ...      ...
# 1195    ozhomedirect           2         Fashion    9.99      14.99        1
# 1196          trainz           6  Toys & Hobbies    4.99       9.99        1
# 1197        fullstar           4    Collectibles    9.99      14.99        1
# 1198      premium247           3           Books    9.99      14.99        1
# 1199         pokiboy           2         Fashion    9.99      14.99        1
#
# [1200 rows x 30 columns]

# %%
#display(df.stb.missing(style=True))
# Out:
# <style type="text/css">
# </style>
# <table id="T_01883_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >missing</th>
#       <th class="col_heading level0 col1" >total</th>
#       <th class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01883_level0_row0" class="row_heading level0 row0" >group</th>
#       <td id="T_01883_row0_col0" class="data row0 col0" >11</td>
#       <td id="T_01883_row0_col1" class="data row0 col1" >1,200</td>
#       <td id="T_01883_row0_col2" class="data row0 col2" >0.92%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row1" class="row_heading level0 row1" >description</th>
#       <td id="T_01883_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_01883_row1_col1" class="data row1 col1" >1,200</td>
#       <td id="T_01883_row1_col2" class="data row1 col2" >0.92%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row2" class="row_heading level0 row2" >ab_end_date</th>
#       <td id="T_01883_row2_col0" class="data row2 col0" >11</td>
#       <td id="T_01883_row2_col1" class="data row2 col1" >1,200</td>
#       <td id="T_01883_row2_col2" class="data row2 col2" >0.92%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row3" class="row_heading level0 row3" >ab_test_id</th>
#       <td id="T_01883_row3_col0" class="data row3 col0" >11</td>
#       <td id="T_01883_row3_col1" class="data row3 col1" >1,200</td>
#       <td id="T_01883_row3_col2" class="data row3 col2" >0.92%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row4" class="row_heading level0 row4" >id</th>
#       <td id="T_01883_row4_col0" class="data row4 col0" >11</td>
#       <td id="T_01883_row4_col1" class="data row4 col1" >1,200</td>
#       <td id="T_01883_row4_col2" class="data row4 col2" >0.92%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row5" class="row_heading level0 row5" >ab_start_date</th>
#       <td id="T_01883_row5_col0" class="data row5 col0" >11</td>
#       <td id="T_01883_row5_col1" class="data row5 col1" >1,200</td>
#       <td id="T_01883_row5_col2" class="data row5 col2" >0.92%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row6" class="row_heading level0 row6" >other_ship</th>
#       <td id="T_01883_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_01883_row6_col1" class="data row6 col1" >1,200</td>
#       <td id="T_01883_row6_col2" class="data row6 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row7" class="row_heading level0 row7" >us_ship</th>
#       <td id="T_01883_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_01883_row7_col1" class="data row7 col1" >1,200</td>
#       <td id="T_01883_row7_col2" class="data row7 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row8" class="row_heading level0 row8" >category</th>
#       <td id="T_01883_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_01883_row8_col1" class="data row8 col1" >1,200</td>
#       <td id="T_01883_row8_col2" class="data row8 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row9" class="row_heading level0 row9" >category_id</th>
#       <td id="T_01883_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_01883_row9_col1" class="data row9 col1" >1,200</td>
#       <td id="T_01883_row9_col2" class="data row9 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row10" class="row_heading level0 row10" >vendor</th>
#       <td id="T_01883_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_01883_row10_col1" class="data row10 col1" >1,200</td>
#       <td id="T_01883_row10_col2" class="data row10 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row11" class="row_heading level0 row11" >vendor_id</th>
#       <td id="T_01883_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_01883_row11_col1" class="data row11 col1" >1,200</td>
#       <td id="T_01883_row11_col2" class="data row11 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row12" class="row_heading level0 row12" >item</th>
#       <td id="T_01883_row12_col0" class="data row12 col0" >0</td>
#       <td id="T_01883_row12_col1" class="data row12 col1" >1,200</td>
#       <td id="T_01883_row12_col2" class="data row12 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row13" class="row_heading level0 row13" >price</th>
#       <td id="T_01883_row13_col0" class="data row13 col0" >0</td>
#       <td id="T_01883_row13_col1" class="data row13 col1" >1,200</td>
#       <td id="T_01883_row13_col2" class="data row13 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row14" class="row_heading level0 row14" >item_id</th>
#       <td id="T_01883_row14_col0" class="data row14 col0" >0</td>
#       <td id="T_01883_row14_col1" class="data row14 col1" >1,200</td>
#       <td id="T_01883_row14_col2" class="data row14 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row15" class="row_heading level0 row15" >amount</th>
#       <td id="T_01883_row15_col0" class="data row15 col0" >0</td>
#       <td id="T_01883_row15_col1" class="data row15 col1" >1,200</td>
#       <td id="T_01883_row15_col2" class="data row15 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row16" class="row_heading level0 row16" >order_id</th>
#       <td id="T_01883_row16_col0" class="data row16 col0" >0</td>
#       <td id="T_01883_row16_col1" class="data row16 col1" >1,200</td>
#       <td id="T_01883_row16_col2" class="data row16 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row17" class="row_heading level0 row17" >date</th>
#       <td id="T_01883_row17_col0" class="data row17 col0" >0</td>
#       <td id="T_01883_row17_col1" class="data row17 col1" >1,200</td>
#       <td id="T_01883_row17_col2" class="data row17 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row18" class="row_heading level0 row18" >country</th>
#       <td id="T_01883_row18_col0" class="data row18 col0" >0</td>
#       <td id="T_01883_row18_col1" class="data row18 col1" >1,200</td>
#       <td id="T_01883_row18_col2" class="data row18 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row19" class="row_heading level0 row19" >symbol</th>
#       <td id="T_01883_row19_col0" class="data row19 col0" >0</td>
#       <td id="T_01883_row19_col1" class="data row19 col1" >1,200</td>
#       <td id="T_01883_row19_col2" class="data row19 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row20" class="row_heading level0 row20" >country_id</th>
#       <td id="T_01883_row20_col0" class="data row20 col0" >0</td>
#       <td id="T_01883_row20_col1" class="data row20 col1" >1,200</td>
#       <td id="T_01883_row20_col2" class="data row20 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row21" class="row_heading level0 row21" >gender</th>
#       <td id="T_01883_row21_col0" class="data row21 col0" >0</td>
#       <td id="T_01883_row21_col1" class="data row21 col1" >1,200</td>
#       <td id="T_01883_row21_col2" class="data row21 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row22" class="row_heading level0 row22" >membership</th>
#       <td id="T_01883_row22_col0" class="data row22 col0" >0</td>
#       <td id="T_01883_row22_col1" class="data row22 col1" >1,200</td>
#       <td id="T_01883_row22_col2" class="data row22 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row23" class="row_heading level0 row23" >customer_id</th>
#       <td id="T_01883_row23_col0" class="data row23 col0" >0</td>
#       <td id="T_01883_row23_col1" class="data row23 col1" >1,200</td>
#       <td id="T_01883_row23_col2" class="data row23 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_level0_row24" class="row_heading level0 row24" >camp_end_date</th>
#       <td id="T_01883_row24_col0" class="data row24 col0" >0</td>
#       <td id="T_01883_row24_col1" class="data row24 col1" >1,200</td>
#       <td id="T_01883_row24_col2" class="data row24 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_01883_lev

# %%
display(df.columns)
for col in df.columns:
    display('col:',col, df[df[col].isna()])
# Out:
# Index(['order_id', 'date', 'registration', 'campaign_id', 'source',
#        'camp_start_date', 'camp_end_date', 'customer_id', 'membership',
#        'gender', 'country_id', 'symbol', 'country', 'ab_test_id', 'id',
#        'group', 'description', 'ab_start_date', 'ab_end_date', 'amount',
#        'item_id', 'price', 'item', 'vendor_id', 'vendor', 'category_id',
#        'category', 'us_ship', 'other_ship', 'duprank'],
#       dtype='object')
# 'col:'
# 'order_id'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'date'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'registration'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'campaign_id'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'source'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'camp_start_date'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'camp_end_date'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'customer_id'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'membership'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'gender'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'country_id'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'symbol'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'country'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'ab_test_id'
#       order_id       date                    registration  campaign_id  \
# 921        922 2021-03-12   (56,"2021-02-16 00:00:00",11)           11
# 983        984 2021-04-21  (177,"2021-02-01 00:00:00",11)           11
# 1048      1049 2021-05-26  (479,"2021-03-12 00:00:00",14)           14
# 1089      1090 2021-06-19  (197,"2021-06-09 00:00:00",13)           13
# 1109      1110 2021-06-27   (56,"2021-02-16 00:00:00",11)           11
# 1138      1139 2021-07-10  (210,"2021-05-28 00:00:00",14)           14
# 1157      1158 2021-07-23  (267,"2021-03-10 00:00:00",12)           12
# 1168      1169 2021-07-31  (164,"2021-04-30 00:00:00",12)           12
# 1178      1179 2021-08-02  (305,"2021-02-11 00:00:00",11)           11
# 1196      1197 2021-08-05   (68,"2021-08-05 00:00:00",14)           14
# 1197      1198 2021-08-05  (306,"2021-03-02 00:00:00",12)           12
#
#           source camp_start_date camp_end_date  customer_id membership  \
# 921     Facebook      2020-11-13    2021-03-10           56        yes
# 983     Facebook      2020-11-13    2021-03-10          177        yes
# 1048  Google Ads      2021-03-12    2021-08-05          479         no
# 1089    Facebook      2021-04-01    2021-07-12          197         no
# 1109    Facebook      2020-11-13    2021-03-10           56        yes
# 1138  Google Ads      2021-03-12    2021-08-05          210        yes
# 1157     YouTube      2021-02-23    2021-06-30          267         no
# 1168     YouTube      2021-02-23    2021-06-30          164        yes
# 1178    Facebook      2020-11-13    2021-03-10          305        yes
# 1196  Google Ads      2021-03-12    2021-08-05           68         no
# 1197     YouTube      2021-02-23    2021-06-30          306         no
#
#       gender  ...  item_id   price  \
# 921   Female  ...       41   13.49
# 983   Female  ...      102   59.99
# 1048    Male  ...       42  320.00
# 1089  Female  ...       38  120.00
# 1109  Female  ...      121   45.99
# 1138  Female  ...        4   25.99
# 1157  Female  ...      142   72.99
# 1168    Male  ...       11   19.49
# 1178  Female  ...       77   77.50
# 1196  Female  ...      161    8.96
# 1197    Male  ...       49   28.79
#
#                                                    item  vendor_id  \
# 921                      Eye Shadow Palette - 15 shades         24
# 983                    One Piece Vol.1 1st Edition - JP          9
# 1048                                          Face Mask         24
# 1089  Dragon Ball Z - Officially Licensed Dragon Bal...         15
# 1109  Roku Streaming Stick With HD/4K/HDR Streaming ...          1
# 1138  12/14 inch long Aluminum Pizza Shovel With Lon...         18
# 1157  Timberland Brooklyn Alpine Chukka Black Nubuck...          2
# 1168                           500 Pieces Castle Puzzle         20
# 1178                                       Lego Classic         13
# 1196                                            Yahtzee         20
# 1197                   Funko Pop! PAIN Glow In The Dark          7
#
#                     vendor category_id        category us_ship other_ship  \
# 921                beautyo          10     Beauty Care    9.99      19.99
# 983      excellent-shop666           3           Books    9.99      14.99
# 1048               beautyo          10     Beauty Care    9.99      19.99
# 1089                pixfab           4    Collectibles    9.99      14.99
# 1109                doronk           1     Electronics   19.99      24.99
# 1138  magicglobalgadgets17           8         Kitchen    9.99      14.99
# 1157                zoro12           2         Fashion    9.99      14.99
# 1168                trainz           6  Toys & Hobbies    4.99       9.99
# 1178          ignitionline           6  Toys & Hobbies    4.99       9.99
# 1196                trainz           6  Toys & Hobbies    4.99       9.99
# 1197              fullstar           4    Collectibles    9.99      14.99
#
#       duprank
# 921         1
# 983         1
# 1048        1
# 1089        1
# 1109        1
# 1138        1
# 1157        1
# 1168        1
# 1178        1
# 1196        1
# 1197        1
#
# [11 rows x 30 columns]
# 'col:'
# 'id'
#       order_id       date                    registration  campaign_id  \
# 921        922 2021-03-12   (56,"2021-02-16 00:00:00",11)           11
# 983        984 2021-04-21  (177,"2021-02-01 00:00:00",11)           11
# 1048      1049 2021-05-26  (479,"2021-03-12 00:00:00",14)           14
# 1089      1090 2021-06-19  (197,"2021-06-09 00:00:00",13)           13
# 1109      1110 2021-06-27   (56,"2021-02-16 00:00:00",11)           11
# 1138      1139 2021-07-10  (210,"2021-05-28 00:00:00",14)           14
# 1157      1158 2021-07-23  (267,"2021-03-10 00:00:00",12)           12
# 1168      1169 2021-07-31  (164,"2021-04-30 00:00:00",12)           12
# 1178      1179 2021-08-02  (305,"2021-02-11 00:00:00",11)           11
# 1196      1197 2021-08-05   (68,"2021-08-05 00:00:00",14)           14
# 1197      1198 2021-08-05  (306,"2021-03-02 00:00:00",12)           12
#
#           source camp_start_date camp_end_date  customer_id membership  \
# 921     Facebook      2020-11-13    2021-03-10           56        yes
# 983     Facebook      2020-11-13    2021-03-10          177        yes
# 1048  Google Ads      2021-03-12    2021-08-05          479         no
# 1089    Facebook      2021-04-01    2021-07-12          197         no
# 1109    Facebook      2020-11-13    2021-03-10           56        yes
# 1138  Google Ads      2021-03-12    2021-08-05          210        yes
# 1157     YouTube      2021-02-23    2021-06-30          267         no
# 1168     YouTube      2021-02-23    2021-06-30          164        yes
# 1178    Facebook      2020-11-13    2021-03-10          305        yes
# 1196  Google Ads      2021-03-12    2021-08-05           68         no
# 1197     YouTube      2021-02-23    2021-06-30          306         no
#
#       gender  ...  item_id   price  \
# 921   Female  ...       41   13.49
# 983   Female  ...      102   59.99
# 1048    Male  ...       42  320.00
# 1089  Female  ...       38  120.00
# 1109  Female  ...      121   45.99
# 1138  Female  ...        4   25.99
# 1157  Female  ...      142   72.99
# 1168    Male  ...       11   19.49
# 1178  Female  ...       77   77.50
# 1196  Female  ...      161    8.96
# 1197    Male  ...       49   28.79
#
#                                                    item  vendor_id  \
# 921                      Eye Shadow Palette - 15 shades         24
# 983                    One Piece Vol.1 1st Edition - JP          9
# 1048                                          Face Mask         24
# 1089  Dragon Ball Z - Officially Licensed Dragon Bal...         15
# 1109  Roku Streaming Stick With HD/4K/HDR Streaming ...          1
# 1138  12/14 inch long Aluminum Pizza Shovel With Lon...         18
# 1157  Timberland Brooklyn Alpine Chukka Black Nubuck...          2
# 1168                           500 Pieces Castle Puzzle         20
# 1178                                       Lego Classic         13
# 1196                                            Yahtzee         20
# 1197                   Funko Pop! PAIN Glow In The Dark          7
#
#                     vendor category_id        category us_ship other_ship  \
# 921                beautyo          10     Beauty Care    9.99      19.99
# 983      excellent-shop666           3           Books    9.99      14.99
# 1048               beautyo          10     Beauty Care    9.99      19.99
# 1089                pixfab           4    Collectibles    9.99      14.99
# 1109                doronk           1     Electronics   19.99      24.99
# 1138  magicglobalgadgets17           8         Kitchen    9.99      14.99
# 1157                zoro12           2         Fashion    9.99      14.99
# 1168                trainz           6  Toys & Hobbies    4.99       9.99
# 1178          ignitionline           6  Toys & Hobbies    4.99       9.99
# 1196                trainz           6  Toys & Hobbies    4.99       9.99
# 1197              fullstar           4    Collectibles    9.99      14.99
#
#       duprank
# 921         1
# 983         1
# 1048        1
# 1089        1
# 1109        1
# 1138        1
# 1157        1
# 1168        1
# 1178        1
# 1196        1
# 1197        1
#
# [11 rows x 30 columns]
# 'col:'
# 'group'
#       order_id       date                    registration  campaign_id  \
# 921        922 2021-03-12   (56,"2021-02-16 00:00:00",11)           11
# 983        984 2021-04-21  (177,"2021-02-01 00:00:00",11)           11
# 1048      1049 2021-05-26  (479,"2021-03-12 00:00:00",14)           14
# 1089      1090 2021-06-19  (197,"2021-06-09 00:00:00",13)           13
# 1109      1110 2021-06-27   (56,"2021-02-16 00:00:00",11)           11
# 1138      1139 2021-07-10  (210,"2021-05-28 00:00:00",14)           14
# 1157      1158 2021-07-23  (267,"2021-03-10 00:00:00",12)           12
# 1168      1169 2021-07-31  (164,"2021-04-30 00:00:00",12)           12
# 1178      1179 2021-08-02  (305,"2021-02-11 00:00:00",11)           11
# 1196      1197 2021-08-05   (68,"2021-08-05 00:00:00",14)           14
# 1197      1198 2021-08-05  (306,"2021-03-02 00:00:00",12)           12
#
#           source camp_start_date camp_end_date  customer_id membership  \
# 921     Facebook      2020-11-13    2021-03-10           56        yes
# 983     Facebook      2020-11-13    2021-03-10          177        yes
# 1048  Google Ads      2021-03-12    2021-08-05          479         no
# 1089    Facebook      2021-04-01    2021-07-12          197         no
# 1109    Facebook      2020-11-13    2021-03-10           56        yes
# 1138  Google Ads      2021-03-12    2021-08-05          210        yes
# 1157     YouTube      2021-02-23    2021-06-30          267         no
# 1168     YouTube      2021-02-23    2021-06-30          164        yes
# 1178    Facebook      2020-11-13    2021-03-10          305        yes
# 1196  Google Ads      2021-03-12    2021-08-05           68         no
# 1197     YouTube      2021-02-23    2021-06-30          306         no
#
#       gender  ...  item_id   price  \
# 921   Female  ...       41   13.49
# 983   Female  ...      102   59.99
# 1048    Male  ...       42  320.00
# 1089  Female  ...       38  120.00
# 1109  Female  ...      121   45.99
# 1138  Female  ...        4   25.99
# 1157  Female  ...      142   72.99
# 1168    Male  ...       11   19.49
# 1178  Female  ...       77   77.50
# 1196  Female  ...      161    8.96
# 1197    Male  ...       49   28.79
#
#                                                    item  vendor_id  \
# 921                      Eye Shadow Palette - 15 shades         24
# 983                    One Piece Vol.1 1st Edition - JP          9
# 1048                                          Face Mask         24
# 1089  Dragon Ball Z - Officially Licensed Dragon Bal...         15
# 1109  Roku Streaming Stick With HD/4K/HDR Streaming ...          1
# 1138  12/14 inch long Aluminum Pizza Shovel With Lon...         18
# 1157  Timberland Brooklyn Alpine Chukka Black Nubuck...          2
# 1168                           500 Pieces Castle Puzzle         20
# 1178                                       Lego Classic         13
# 1196                                            Yahtzee         20
# 1197                   Funko Pop! PAIN Glow In The Dark          7
#
#                     vendor category_id        category us_ship other_ship  \
# 921                beautyo          10     Beauty Care    9.99      19.99
# 983      excellent-shop666           3           Books    9.99      14.99
# 1048               beautyo          10     Beauty Care    9.99      19.99
# 1089                pixfab           4    Collectibles    9.99      14.99
# 1109                doronk           1     Electronics   19.99      24.99
# 1138  magicglobalgadgets17           8         Kitchen    9.99      14.99
# 1157                zoro12           2         Fashion    9.99      14.99
# 1168                trainz           6  Toys & Hobbies    4.99       9.99
# 1178          ignitionline           6  Toys & Hobbies    4.99       9.99
# 1196                trainz           6  Toys & Hobbies    4.99       9.99
# 1197              fullstar           4    Collectibles    9.99      14.99
#
#       duprank
# 921         1
# 983         1
# 1048        1
# 1089        1
# 1109        1
# 1138        1
# 1157        1
# 1168        1
# 1178        1
# 1196        1
# 1197        1
#
# [11 rows x 30 columns]
# 'col:'
# 'description'
#       order_id       date                    registration  campaign_id  \
# 921        922 2021-03-12   (56,"2021-02-16 00:00:00",11)           11
# 983        984 2021-04-21  (177,"2021-02-01 00:00:00",11)           11
# 1048      1049 2021-05-26  (479,"2021-03-12 00:00:00",14)           14
# 1089      1090 2021-06-19  (197,"2021-06-09 00:00:00",13)           13
# 1109      1110 2021-06-27   (56,"2021-02-16 00:00:00",11)           11
# 1138      1139 2021-07-10  (210,"2021-05-28 00:00:00",14)           14
# 1157      1158 2021-07-23  (267,"2021-03-10 00:00:00",12)           12
# 1168      1169 2021-07-31  (164,"2021-04-30 00:00:00",12)           12
# 1178      1179 2021-08-02  (305,"2021-02-11 00:00:00",11)           11
# 1196      1197 2021-08-05   (68,"2021-08-05 00:00:00",14)           14
# 1197      1198 2021-08-05  (306,"2021-03-02 00:00:00",12)           12
#
#           source camp_start_date camp_end_date  customer_id membership  \
# 921     Facebook      2020-11-13    2021-03-10           56        yes
# 983     Facebook      2020-11-13    2021-03-10          177        yes
# 1048  Google Ads      2021-03-12    2021-08-05          479         no
# 1089    Facebook      2021-04-01    2021-07-12          197         no
# 1109    Facebook      2020-11-13    2021-03-10           56        yes
# 1138  Google Ads      2021-03-12    2021-08-05          210        yes
# 1157     YouTube      2021-02-23    2021-06-30          267         no
# 1168     YouTube      2021-02-23    2021-06-30          164        yes
# 1178    Facebook      2020-11-13    2021-03-10          305        yes
# 1196  Google Ads      2021-03-12    2021-08-05           68         no
# 1197     YouTube      2021-02-23    2021-06-30          306         no
#
#       gender  ...  item_id   price  \
# 921   Female  ...       41   13.49
# 983   Female  ...      102   59.99
# 1048    Male  ...       42  320.00
# 1089  Female  ...       38  120.00
# 1109  Female  ...      121   45.99
# 1138  Female  ...        4   25.99
# 1157  Female  ...      142   72.99
# 1168    Male  ...       11   19.49
# 1178  Female  ...       77   77.50
# 1196  Female  ...      161    8.96
# 1197    Male  ...       49   28.79
#
#                                                    item  vendor_id  \
# 921                      Eye Shadow Palette - 15 shades         24
# 983                    One Piece Vol.1 1st Edition - JP          9
# 1048                                          Face Mask         24
# 1089  Dragon Ball Z - Officially Licensed Dragon Bal...         15
# 1109  Roku Streaming Stick With HD/4K/HDR Streaming ...          1
# 1138  12/14 inch long Aluminum Pizza Shovel With Lon...         18
# 1157  Timberland Brooklyn Alpine Chukka Black Nubuck...          2
# 1168                           500 Pieces Castle Puzzle         20
# 1178                                       Lego Classic         13
# 1196                                            Yahtzee         20
# 1197                   Funko Pop! PAIN Glow In The Dark          7
#
#                     vendor category_id        category us_ship other_ship  \
# 921                beautyo          10     Beauty Care    9.99      19.99
# 983      excellent-shop666           3           Books    9.99      14.99
# 1048               beautyo          10     Beauty Care    9.99      19.99
# 1089                pixfab           4    Collectibles    9.99      14.99
# 1109                doronk           1     Electronics   19.99      24.99
# 1138  magicglobalgadgets17           8         Kitchen    9.99      14.99
# 1157                zoro12           2         Fashion    9.99      14.99
# 1168                trainz           6  Toys & Hobbies    4.99       9.99
# 1178          ignitionline           6  Toys & Hobbies    4.99       9.99
# 1196                trainz           6  Toys & Hobbies    4.99       9.99
# 1197              fullstar           4    Collectibles    9.99      14.99
#
#       duprank
# 921         1
# 983         1
# 1048        1
# 1089        1
# 1109        1
# 1138        1
# 1157        1
# 1168        1
# 1178        1
# 1196        1
# 1197        1
#
# [11 rows x 30 columns]
# 'col:'
# 'ab_start_date'
#       order_id       date                    registration  campaign_id  \
# 921        922 2021-03-12   (56,"2021-02-16 00:00:00",11)           11
# 983        984 2021-04-21  (177,"2021-02-01 00:00:00",11)           11
# 1048      1049 2021-05-26  (479,"2021-03-12 00:00:00",14)           14
# 1089      1090 2021-06-19  (197,"2021-06-09 00:00:00",13)           13
# 1109      1110 2021-06-27   (56,"2021-02-16 00:00:00",11)           11
# 1138      1139 2021-07-10  (210,"2021-05-28 00:00:00",14)           14
# 1157      1158 2021-07-23  (267,"2021-03-10 00:00:00",12)           12
# 1168      1169 2021-07-31  (164,"2021-04-30 00:00:00",12)           12
# 1178      1179 2021-08-02  (305,"2021-02-11 00:00:00",11)           11
# 1196      1197 2021-08-05   (68,"2021-08-05 00:00:00",14)           14
# 1197      1198 2021-08-05  (306,"2021-03-02 00:00:00",12)           12
#
#           source camp_start_date camp_end_date  customer_id membership  \
# 921     Facebook      2020-11-13    2021-03-10           56        yes
# 983     Facebook      2020-11-13    2021-03-10          177        yes
# 1048  Google Ads      2021-03-12    2021-08-05          479         no
# 1089    Facebook      2021-04-01    2021-07-12          197         no
# 1109    Facebook      2020-11-13    2021-03-10           56        yes
# 1138  Google Ads      2021-03-12    2021-08-05          210        yes
# 1157     YouTube      2021-02-23    2021-06-30          267         no
# 1168     YouTube      2021-02-23    2021-06-30          164        yes
# 1178    Facebook      2020-11-13    2021-03-10          305        yes
# 1196  Google Ads      2021-03-12    2021-08-05           68         no
# 1197     YouTube      2021-02-23    2021-06-30          306         no
#
#       gender  ...  item_id   price  \
# 921   Female  ...       41   13.49
# 983   Female  ...      102   59.99
# 1048    Male  ...       42  320.00
# 1089  Female  ...       38  120.00
# 1109  Female  ...      121   45.99
# 1138  Female  ...        4   25.99
# 1157  Female  ...      142   72.99
# 1168    Male  ...       11   19.49
# 1178  Female  ...       77   77.50
# 1196  Female  ...      161    8.96
# 1197    Male  ...       49   28.79
#
#                                                    item  vendor_id  \
# 921                      Eye Shadow Palette - 15 shades         24
# 983                    One Piece Vol.1 1st Edition - JP          9
# 1048                                          Face Mask         24
# 1089  Dragon Ball Z - Officially Licensed Dragon Bal...         15
# 1109  Roku Streaming Stick With HD/4K/HDR Streaming ...          1
# 1138  12/14 inch long Aluminum Pizza Shovel With Lon...         18
# 1157  Timberland Brooklyn Alpine Chukka Black Nubuck...          2
# 1168                           500 Pieces Castle Puzzle         20
# 1178                                       Lego Classic         13
# 1196                                            Yahtzee         20
# 1197                   Funko Pop! PAIN Glow In The Dark          7
#
#                     vendor category_id        category us_ship other_ship  \
# 921                beautyo          10     Beauty Care    9.99      19.99
# 983      excellent-shop666           3           Books    9.99      14.99
# 1048               beautyo          10     Beauty Care    9.99      19.99
# 1089                pixfab           4    Collectibles    9.99      14.99
# 1109                doronk           1     Electronics   19.99      24.99
# 1138  magicglobalgadgets17           8         Kitchen    9.99      14.99
# 1157                zoro12           2         Fashion    9.99      14.99
# 1168                trainz           6  Toys & Hobbies    4.99       9.99
# 1178          ignitionline           6  Toys & Hobbies    4.99       9.99
# 1196                trainz           6  Toys & Hobbies    4.99       9.99
# 1197              fullstar           4    Collectibles    9.99      14.99
#
#       duprank
# 921         1
# 983         1
# 1048        1
# 1089        1
# 1109        1
# 1138        1
# 1157        1
# 1168        1
# 1178        1
# 1196        1
# 1197        1
#
# [11 rows x 30 columns]
# 'col:'
# 'ab_end_date'
#       order_id       date                    registration  campaign_id  \
# 921        922 2021-03-12   (56,"2021-02-16 00:00:00",11)           11
# 983        984 2021-04-21  (177,"2021-02-01 00:00:00",11)           11
# 1048      1049 2021-05-26  (479,"2021-03-12 00:00:00",14)           14
# 1089      1090 2021-06-19  (197,"2021-06-09 00:00:00",13)           13
# 1109      1110 2021-06-27   (56,"2021-02-16 00:00:00",11)           11
# 1138      1139 2021-07-10  (210,"2021-05-28 00:00:00",14)           14
# 1157      1158 2021-07-23  (267,"2021-03-10 00:00:00",12)           12
# 1168      1169 2021-07-31  (164,"2021-04-30 00:00:00",12)           12
# 1178      1179 2021-08-02  (305,"2021-02-11 00:00:00",11)           11
# 1196      1197 2021-08-05   (68,"2021-08-05 00:00:00",14)           14
# 1197      1198 2021-08-05  (306,"2021-03-02 00:00:00",12)           12
#
#           source camp_start_date camp_end_date  customer_id membership  \
# 921     Facebook      2020-11-13    2021-03-10           56        yes
# 983     Facebook      2020-11-13    2021-03-10          177        yes
# 1048  Google Ads      2021-03-12    2021-08-05          479         no
# 1089    Facebook      2021-04-01    2021-07-12          197         no
# 1109    Facebook      2020-11-13    2021-03-10           56        yes
# 1138  Google Ads      2021-03-12    2021-08-05          210        yes
# 1157     YouTube      2021-02-23    2021-06-30          267         no
# 1168     YouTube      2021-02-23    2021-06-30          164        yes
# 1178    Facebook      2020-11-13    2021-03-10          305        yes
# 1196  Google Ads      2021-03-12    2021-08-05           68         no
# 1197     YouTube      2021-02-23    2021-06-30          306         no
#
#       gender  ...  item_id   price  \
# 921   Female  ...       41   13.49
# 983   Female  ...      102   59.99
# 1048    Male  ...       42  320.00
# 1089  Female  ...       38  120.00
# 1109  Female  ...      121   45.99
# 1138  Female  ...        4   25.99
# 1157  Female  ...      142   72.99
# 1168    Male  ...       11   19.49
# 1178  Female  ...       77   77.50
# 1196  Female  ...      161    8.96
# 1197    Male  ...       49   28.79
#
#                                                    item  vendor_id  \
# 921                      Eye Shadow Palette - 15 shades         24
# 983                    One Piece Vol.1 1st Edition - JP          9
# 1048                                          Face Mask         24
# 1089  Dragon Ball Z - Officially Licensed Dragon Bal...         15
# 1109  Roku Streaming Stick With HD/4K/HDR Streaming ...          1
# 1138  12/14 inch long Aluminum Pizza Shovel With Lon...         18
# 1157  Timberland Brooklyn Alpine Chukka Black Nubuck...          2
# 1168                           500 Pieces Castle Puzzle         20
# 1178                                       Lego Classic         13
# 1196                                            Yahtzee         20
# 1197                   Funko Pop! PAIN Glow In The Dark          7
#
#                     vendor category_id        category us_ship other_ship  \
# 921                beautyo          10     Beauty Care    9.99      19.99
# 983      excellent-shop666           3           Books    9.99      14.99
# 1048               beautyo          10     Beauty Care    9.99      19.99
# 1089                pixfab           4    Collectibles    9.99      14.99
# 1109                doronk           1     Electronics   19.99      24.99
# 1138  magicglobalgadgets17           8         Kitchen    9.99      14.99
# 1157                zoro12           2         Fashion    9.99      14.99
# 1168                trainz           6  Toys & Hobbies    4.99       9.99
# 1178          ignitionline           6  Toys & Hobbies    4.99       9.99
# 1196                trainz           6  Toys & Hobbies    4.99       9.99
# 1197              fullstar           4    Collectibles    9.99      14.99
#
#       duprank
# 921         1
# 983         1
# 1048        1
# 1089        1
# 1109        1
# 1138        1
# 1157        1
# 1168        1
# 1178        1
# 1196        1
# 1197        1
#
# [11 rows x 30 columns]
# 'col:'
# 'amount'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'item_id'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'price'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'item'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'vendor_id'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'vendor'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'category_id'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'category'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'us_ship'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'other_ship'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'col:'
# 'duprank'
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]

# %%
df[df.isna().any(axis=0)].ab_test_id
# Out:
# C:\Users\611D~1\AppData\Local\Temp/ipykernel_12136/2152623369.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.isna().any(axis=0)].ab_test_id
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# C:\Users\611D~1\AppData\Local\Temp/ipykernel_12136/2152623369.py in <module>
# ----> 1 df[df.isna().any(axis=0)].ab_test_id
#
# C:\anaconda\envs\TF-2.5\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3444         # Do we have a (boolean) 1d indexer?
#    3445         if com.is_bool_indexer(key):
# -> 3446             return self._getitem_bool_array(key)
#    3447
#    3448         # We are left with two options: a single key, and a collection of keys,
#
# C:\anaconda\envs\TF-2.5\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3497         # check_bool_indexer will throw exception if Series key cannot
#    3498         # be reindexed to match DataFrame rows
# -> 3499         key = check_bool_indexer(self.index, key)
#    3500         indexer = key.nonzero()[0]
#    3501         return self._take_with_is_copy(indexer, axis=0)
#
# C:\anaconda\envs\TF-2.5\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2386         mask = isna(result._values)
#    2387         if mask.any():
# -> 2388             raise IndexingError(
#    2389                 "Unalignable boolean Series provided as "
#    2390                 "indexer (index of the boolean Series and of "
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
df.iloc[1157]

# %%
query1 = '''
            select
                *
            from
                ab_allocation
         '''


df = queryResult(query1)

display('duplicated: ',df[df.duplicated()])
display('na:', df[df.isna().any(axis=1)])
display('no filter: ',df)

# %%
query1 = '''
            select *
            from ab_info         
         '''


df = queryResult(query1)

display('duplicated: ',df[df.duplicated()])
display('na:', df[df.isna().any(axis=1)])
display('no filter: ',df)
# Out:
# 'duplicated: '
# Empty DataFrame
# Columns: [ab_test_id, description, start_date, end_date]
# Index: []
# 'na:'
# Empty DataFrame
# Columns: [ab_test_id, description, start_date, end_date]
# Index: []
# 'no filter: '
#    ab_test_id                                        description start_date  \
# 0           1    Changing color of background from blue to green 2019-10-02
# 1           2  Showing 5 recommendation instead of 3 on each ... 2020-01-04
# 2           3      Showing discount on the products page as well 2020-03-11
# 3           4         Adding a remember me on this device option 2020-06-01
# 4           5             Use a relaxing music in the background 2021-02-08
#
#     end_date
# 0 2019-11-30
# 1 2020-02-14
# 2 2020-04-30
# 3 2020-07-15
# 4 2021-04-13

# %%
query1 = '''
            select
                *
            from
            (
                select  
                    orders.order_id, orders.date,
                    Registration,
                    campaign.campaign_id, campaign.source,  campaign.start_date as camp_start_date, campaign.end_date as camp_end_date,
                    customer_info.customer_id, customer_info.membership, customer_info.gender,
                    countries.country_id, countries.symbol, countries.country,
                    ab_allocation.ab_test_id, ab_allocation.id, ab_allocation.group,
                    ab_info.description, ab_info.start_date as ab_start_date, ab_info.end_date as ab_end_date,
                    order_details.amount,
                    items.item_id, items.price, items.item,
                    vendors.vendor_id, vendors.vendor,
                    categories.category_id, categories.category, categories.us_ship, categories.other_ship,
                    row_number() over (partition by orders.order_id order BY (select null)) as duprank
                from 
                    orders 
                    left join registration on orders.customer_id = registration.customer_id
                    left join campaign on campaign.campaign_id = registration.campaign_id
                    left join customer_info on customer_info.customer_id = orders.customer_id
                    left join countries on countries.country_id = customer_info.country_id
                    left join ab_allocation on ab_allocation.customer_id = customer_info.customer_id and ab_allocation.customer_id = orders.customer_id
                    left join ab_info on ab_info.ab_test_id = ab_allocation.ab_test_id
                    left join order_details on order_details.order_id = orders.order_id
                    left join items on items.item_id = order_details.item_id
                    left join vendors on vendors.vendor_id = items.vendor_id
                    left join categories on categories.category_id = items.category_id
            ) as T
            WHERE duprank = 1 
         '''


df = queryResult(query1)

display('duplicated: ',df[df.duplicated()])
display('na:', df[df.isna().any(axis=1)])
display('no filter: ',df)
# Out:
# 'duplicated: '
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, description, ab_start_date, ab_end_date, amount, item_id, price, item, vendor_id, vendor, category_id, category, us_ship, other_ship, duprank]
# Index: []
#
# [0 rows x 30 columns]
# 'na:'
#       order_id       date                    registration  campaign_id  \
# 921        922 2021-03-12   (56,"2021-02-16 00:00:00",11)           11
# 983        984 2021-04-21  (177,"2021-02-01 00:00:00",11)           11
# 1048      1049 2021-05-26  (479,"2021-03-12 00:00:00",14)           14
# 1089      1090 2021-06-19  (197,"2021-06-09 00:00:00",13)           13
# 1109      1110 2021-06-27   (56,"2021-02-16 00:00:00",11)           11
# 1138      1139 2021-07-10  (210,"2021-05-28 00:00:00",14)           14
# 1157      1158 2021-07-23  (267,"2021-03-10 00:00:00",12)           12
# 1168      1169 2021-07-31  (164,"2021-04-30 00:00:00",12)           12
# 1178      1179 2021-08-02  (305,"2021-02-11 00:00:00",11)           11
# 1196      1197 2021-08-05   (68,"2021-08-05 00:00:00",14)           14
# 1197      1198 2021-08-05  (306,"2021-03-02 00:00:00",12)           12
#
#           source camp_start_date camp_end_date  customer_id membership  \
# 921     Facebook      2020-11-13    2021-03-10           56        yes
# 983     Facebook      2020-11-13    2021-03-10          177        yes
# 1048  Google Ads      2021-03-12    2021-08-05          479         no
# 1089    Facebook      2021-04-01    2021-07-12          197         no
# 1109    Facebook      2020-11-13    2021-03-10           56        yes
# 1138  Google Ads      2021-03-12    2021-08-05          210        yes
# 1157     YouTube      2021-02-23    2021-06-30          267         no
# 1168     YouTube      2021-02-23    2021-06-30          164        yes
# 1178    Facebook      2020-11-13    2021-03-10          305        yes
# 1196  Google Ads      2021-03-12    2021-08-05           68         no
# 1197     YouTube      2021-02-23    2021-06-30          306         no
#
#       gender  ...  item_id   price  \
# 921   Female  ...       41   13.49
# 983   Female  ...      102   59.99
# 1048    Male  ...       42  320.00
# 1089  Female  ...       38  120.00
# 1109  Female  ...      121   45.99
# 1138  Female  ...        4   25.99
# 1157  Female  ...      142   72.99
# 1168    Male  ...       11   19.49
# 1178  Female  ...       77   77.50
# 1196  Female  ...      161    8.96
# 1197    Male  ...       49   28.79
#
#                                                    item  vendor_id  \
# 921                      Eye Shadow Palette - 15 shades         24
# 983                    One Piece Vol.1 1st Edition - JP          9
# 1048                                          Face Mask         24
# 1089  Dragon Ball Z - Officially Licensed Dragon Bal...         15
# 1109  Roku Streaming Stick With HD/4K/HDR Streaming ...          1
# 1138  12/14 inch long Aluminum Pizza Shovel With Lon...         18
# 1157  Timberland Brooklyn Alpine Chukka Black Nubuck...          2
# 1168                           500 Pieces Castle Puzzle         20
# 1178                                       Lego Classic         13
# 1196                                            Yahtzee         20
# 1197                   Funko Pop! PAIN Glow In The Dark          7
#
#                     vendor category_id        category us_ship other_ship  \
# 921                beautyo          10     Beauty Care    9.99      19.99
# 983      excellent-shop666           3           Books    9.99      14.99
# 1048               beautyo          10     Beauty Care    9.99      19.99
# 1089                pixfab           4    Collectibles    9.99      14.99
# 1109                doronk           1     Electronics   19.99      24.99
# 1138  magicglobalgadgets17           8         Kitchen    9.99      14.99
# 1157                zoro12           2         Fashion    9.99      14.99
# 1168                trainz           6  Toys & Hobbies    4.99       9.99
# 1178          ignitionline           6  Toys & Hobbies    4.99       9.99
# 1196                trainz           6  Toys & Hobbies    4.99       9.99
# 1197              fullstar           4    Collectibles    9.99      14.99
#
#       duprank
# 921         1
# 983         1
# 1048        1
# 1089        1
# 1109        1
# 1138        1
# 1157        1
# 1168        1
# 1178        1
# 1196        1
# 1197        1
#
# [11 rows x 30 columns]
# 'no filter: '
#       order_id       date                    registration  campaign_id  \
# 0            1 2019-10-02   (214,"2019-06-15 00:00:00",3)            3
# 1            2 2019-10-02   (459,"2019-06-29 00:00:00",2)            2
# 2            3 2019-10-02   (489,"2019-05-29 00:00:00",1)            1
# 3            4 2019-10-03   (127,"2019-05-02 00:00:00",2)            2
# 4            5 2019-10-03   (174,"2019-09-24 00:00:00",3)            3
# ...        ...        ...                             ...          ...
# 1195      1196 2021-08-05    (11,"2020-05-06 00:00:00",9)            9
# 1196      1197 2021-08-05   (68,"2021-08-05 00:00:00",14)           14
# 1197      1198 2021-08-05  (306,"2021-03-02 00:00:00",12)           12
# 1198      1199 2021-08-05  (422,"2020-11-15 00:00:00",10)           10
# 1199      1200 2021-08-05   (485,"2020-08-23 00:00:00",9)            9
#
#           source camp_start_date camp_end_date  customer_id membership  \
# 0     Google Ads      2019-05-30    2019-12-31          214        yes
# 1       Facebook      2019-05-30    2019-12-31          459        yes
# 2        YouTube      2019-05-30    2019-12-31          489         no
# 3       Facebook      2019-05-30    2019-12-31          127        yes
# 4     Google Ads      2019-05-30    2019-12-31          174         no
# ...          ...             ...           ...          ...        ...
# 1195  Google Ads      2020-05-01    2020-09-01           11         no
# 1196  Google Ads      2021-03-12    2021-08-05           68         no
# 1197     YouTube      2021-02-23    2021-06-30          306         no
# 1198     YouTube      2020-08-12    2020-12-31          422         no
# 1199  Google Ads      2020-05-01    2020-09-01          485         no
#
#       gender  ...  item_id   price  \
# 0       Male  ...      156   13.99
# 1     Female  ...       52   84.99
# 2       Male  ...      116   21.95
# 3     Female  ...       30   95.95
# 4       Male  ...      136   29.95
# ...      ...  ...      ...     ...
# 1195    Male  ...       70   21.99
# 1196  Female  ...      161    8.96
# 1197    Male  ...       49   28.79
# 1198  Female  ...      139  139.99
# 1199  Female  ...       23    9.99
#
#                                                    item  vendor_id  \
# 0       Wilson Official Size NFL Ball American Football         21
# 1                      GK61s Mechanical Gaming Keyboard         20
# 2                          Revlon Super Lusrous 3 piece         24
# 3              Cross Trainer Air Walker Glider Home Gym         12
# 4     Star Wars: the Old Republic - Legends Ser.: Fa...          6
# ...                                                 ...        ...
# 1195                                     Kids Gamer Tee          3
# 1196                                            Yahtzee         20
# 1197                   Funko Pop! PAIN Glow In The Dark          7
# 1198                       The Dangling Man 1st Edition         19
# 1199  Best Friend Bracelets for 2 Matching Yin Yang ...          5
#
#               vendor category_id        category us_ship other_ship  duprank
# 0        vhbw-online           5  Sporting Goods   14.99      19.99        1
# 1             trainz           9          Gaming    9.99      14.99        1
# 2            beautyo          10     Beauty Care    9.99      19.99        1
# 3          lumo-shop           5  Sporting Goods   14.99      19.99        1
# 4     senior pac-man           3           Books    9.99      14.99        1
# ...              ...         ...             ...     ...        ...      ...
# 1195    ozhomedirect           2         Fashion    9.99      14.99        1
# 1196          trainz           6  Toys & Hobbies    4.99       9.99        1
# 1197        fullstar           4    Collectibles    9.99      14.99        1
# 1198      premium247           3           Books    9.99      14.99        1
# 1199         pokiboy           2         Fashion    9.99      14.99        1
#
# [1200 rows x 30 columns]

# %%
query1 = '''
            select
                *
            from
            (
                select  
                    orders.order_id, orders.date,
                    Registration,
                    campaign.campaign_id, campaign.source,  campaign.start_date as camp_start_date, campaign.end_date as camp_end_date,
                    customer_info.customer_id, customer_info.membership, customer_info.gender,
                    countries.country_id, countries.symbol, countries.country,
                    ab_allocation.ab_test_id, ab_allocation.id, ab_allocation.group,
                    --ab_inf.description, ab_inf.start_date as ab_start_date, ab_inf.end_date as ab_end_date,
                    --order_details.amount,
                    --items.item_id, items.price, items.item,
                    --vendors.vendor_id, vendors.vendor,
                    --categories.category_id, categories.category, categories.us_ship, categories.other_ship,
                    row_number() over (partition by orders.order_id order BY (select null)) as duprank
                from 
                    orders 
                    left join registration on orders.customer_id = registration.customer_id
                    left join campaign on campaign.campaign_id = registration.campaign_id
                    left join customer_info on customer_info.customer_id = orders.customer_id
                    left join countries on countries.country_id = customer_info.country_id
                    left join ab_allocation on ab_allocation.customer_id = orders.customer_id
                    --left join (select * 
                    --           from ab_info
                    --           where ab_test_id in(select distinct ab_test_id
                    --                               from ab_allocation)) as ab_inf on ab_inf.ab_test_id = ab_allocation.ab_test_id
                    --left join order_details on order_details.order_id = orders.order_id
                    --left join items on items.item_id = order_details.item_id
                    --left join vendors on vendors.vendor_id = items.vendor_id
                    --left join categories on categories.category_id = items.category_id
            ) as T
            WHERE duprank = 1 
         '''
#
#
df = queryResult(query1)

display('duplicated: ',df[df.duplicated()])
display('na:', len(df[df.isna().any(axis=1)]))
display('no filter: ',df)
# Out:
# 'duplicated: '
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, duprank]
# Index: []
# 'na:'
# 11
# 'no filter: '
#       order_id       date                    registration  campaign_id  \
# 0            1 2019-10-02   (214,"2019-06-15 00:00:00",3)            3
# 1            2 2019-10-02   (459,"2019-06-29 00:00:00",2)            2
# 2            3 2019-10-02   (489,"2019-05-29 00:00:00",1)            1
# 3            4 2019-10-03   (127,"2019-05-02 00:00:00",2)            2
# 4            5 2019-10-03   (174,"2019-09-24 00:00:00",3)            3
# ...        ...        ...                             ...          ...
# 1195      1196 2021-08-05    (11,"2020-05-06 00:00:00",9)            9
# 1196      1197 2021-08-05   (68,"2021-08-05 00:00:00",14)           14
# 1197      1198 2021-08-05  (306,"2021-03-02 00:00:00",12)           12
# 1198      1199 2021-08-05  (422,"2020-11-15 00:00:00",10)           10
# 1199      1200 2021-08-05   (485,"2020-08-23 00:00:00",9)            9
#
#           source camp_start_date camp_end_date  customer_id membership  \
# 0     Google Ads      2019-05-30    2019-12-31          214        yes
# 1       Facebook      2019-05-30    2019-12-31          459        yes
# 2        YouTube      2019-05-30    2019-12-31          489         no
# 3       Facebook      2019-05-30    2019-12-31          127        yes
# 4     Google Ads      2019-05-30    2019-12-31          174         no
# ...          ...             ...           ...          ...        ...
# 1195  Google Ads      2020-05-01    2020-09-01           11         no
# 1196  Google Ads      2021-03-12    2021-08-05           68         no
# 1197     YouTube      2021-02-23    2021-06-30          306         no
# 1198     YouTube      2020-08-12    2020-12-31          422         no
# 1199  Google Ads      2020-05-01    2020-09-01          485         no
#
#       gender  country_id symbol        country  ab_test_id      id    group  \
# 0       Male           6     EN        England         5.0  1332.0  control
# 1     Female           3     FR         France         1.0   228.0  control
# 2       Male           7     IT          Italy         5.0  1579.0  control
# 3     Female           5     SW         Sweden         4.0   876.0     test
# 4       Male          11    ROW          Other         5.0  1297.0  control
# ...      ...         ...    ...            ...         ...     ...      ...
# 1195    Male           1     US  United States         5.0  1147.0  control
# 1196  Female           4     SP          Spain         NaN     NaN     None
# 1197    Male           9     PO       Portugal         NaN     NaN     None
# 1198  Female           9     PO       Portugal         5.0  1518.0  control
# 1199  Female           7     IT          Italy         5.0  1573.0     test
#
#       duprank
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 1195        1
# 1196        1
# 1197        1
# 1198        1
# 1199        1
#
# [1200 rows x 17 columns]

# %%
query1 = '''
            select
                *
            from
            (
                select  
                    orders.order_id, orders.date,
                    Registration,
                    campaign.campaign_id, campaign.source,  campaign.start_date as camp_start_date, campaign.end_date as camp_end_date,
                    customer_info.customer_id, customer_info.membership, customer_info.gender,
                    countries.country_id, countries.symbol, countries.country,
                    ab_allocation.ab_test_id, ab_allocation.id, ab_allocation.group,
                    --ab_inf.description, ab_inf.start_date as ab_start_date, ab_inf.end_date as ab_end_date,
                    --order_details.amount,
                    --items.item_id, items.price, items.item,
                    --vendors.vendor_id, vendors.vendor,
                    --categories.category_id, categories.category, categories.us_ship, categories.other_ship,
                    row_number() over (partition by orders.order_id order BY (select null)) as duprank
                from 
                    orders 
                    left join registration on orders.customer_id = registration.customer_id
                    left join campaign on campaign.campaign_id = registration.campaign_id
                    left join customer_info on customer_info.customer_id = orders.customer_id
                    left join countries on countries.country_id = customer_info.country_id
                    left join ab_allocation on ab_allocation.customer_id = orders.customer_id
                    --left join (select * 
                    --           from ab_info
                    --           where ab_test_id in(select distinct ab_test_id
                    --                               from ab_allocation)) as ab_inf on ab_inf.ab_test_id = ab_allocation.ab_test_id
                    --left join order_details on order_details.order_id = orders.order_id
                    --left join items on items.item_id = order_details.item_id
                    --left join vendors on vendors.vendor_id = items.vendor_id
                    --left join categories on categories.category_id = items.category_id
            ) as T
            WHERE duprank = 1 and "id" is not null
         '''
#
#
df = queryResult(query1)

display('duplicated: ',df[df.duplicated()])
display('na:', len(df[df.isna().any(axis=1)]))
display('no filter: ',df)
# Out:
# 'duplicated: '
# Empty DataFrame
# Columns: [order_id, date, registration, campaign_id, source, camp_start_date, camp_end_date, customer_id, membership, gender, country_id, symbol, country, ab_test_id, id, group, duprank]
# Index: []
# 'na:'
# 0
# 'no filter: '
#       order_id       date                    registration  campaign_id  \
# 0            1 2019-10-02   (214,"2019-06-15 00:00:00",3)            3
# 1            2 2019-10-02   (459,"2019-06-29 00:00:00",2)            2
# 2            3 2019-10-02   (489,"2019-05-29 00:00:00",1)            1
# 3            4 2019-10-03   (127,"2019-05-02 00:00:00",2)            2
# 4            5 2019-10-03   (174,"2019-09-24 00:00:00",3)            3
# ...        ...        ...                             ...          ...
# 1184      1194 2021-08-04   (262,"2020-04-08 00:00:00",7)            7
# 1185      1195 2021-08-04   (455,"2019-09-28 00:00:00",3)            3
# 1186      1196 2021-08-05    (11,"2020-05-06 00:00:00",9)            9
# 1187      1199 2021-08-05  (422,"2020-11-15 00:00:00",10)           10
# 1188      1200 2021-08-05   (485,"2020-08-23 00:00:00",9)            9
#
#           source camp_start_date camp_end_date  customer_id membership  \
# 0     Google Ads      2019-05-30    2019-12-31          214        yes
# 1       Facebook      2019-05-30    2019-12-31          459        yes
# 2        YouTube      2019-05-30    2019-12-31          489         no
# 3       Facebook      2019-05-30    2019-12-31          127        yes
# 4     Google Ads      2019-05-30    2019-12-31          174         no
# ...          ...             ...           ...          ...        ...
# 1184     YouTube      2020-03-25    2020-06-30          262         no
# 1185  Google Ads      2019-05-30    2019-12-31          455        yes
# 1186  Google Ads      2020-05-01    2020-09-01           11         no
# 1187     YouTube      2020-08-12    2020-12-31          422         no
# 1188  Google Ads      2020-05-01    2020-09-01          485         no
#
#       gender  country_id symbol        country  ab_test_id    id    group  \
# 0       Male           6     EN        England           5  1332  control
# 1     Female           3     FR         France           1   228  control
# 2       Male           7     IT          Italy           5  1579  control
# 3     Female           5     SW         Sweden           4   876     test
# 4       Male          11    ROW          Other           5  1297  control
# ...      ...         ...    ...            ...         ...   ...      ...
# 1184  Female          11    ROW          Other           4   966     test
# 1185    Male          10     GE        Germany           1   227  control
# 1186    Male           1     US  United States           5  1147  control
# 1187  Female           9     PO       Portugal           5  1518  control
# 1188  Female           7     IT          Italy           5  1573     test
#
#       duprank
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 1184        1
# 1185        1
# 1186        1
# 1187        1
# 1188        1
#
# [1189 rows x 17 columns]

# %%
# export to excel 
df.to_excel("online_shop.xlsx")
